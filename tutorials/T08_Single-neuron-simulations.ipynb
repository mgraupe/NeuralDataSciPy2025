# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: brian2 in /root/venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (3.10.7)
# Requirement already satisfied: brian2tools in /root/venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.3)
# Requirement already satisfied: numpy>=1.23.5 in /root/venv/lib/python3.12/site-packages (from brian2->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: cython>=0.29.21 in /root/venv/lib/python3.12/site-packages (from brian2->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: sympy>=1.2 in /root/venv/lib/python3.12/site-packages (from brian2->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: pyparsing in /root/venv/lib/python3.12/site-packages (from brian2->-r requirements.txt (line 1)) (3.2.5)
# Requirement already satisfied: jinja2>=2.7 in /root/venv/lib/python3.12/site-packages (from brian2->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: setuptools>=61 in /root/venv/lib/python3.12/site-packages (from brian2->-r requirements.txt (line 1)) (80.9.0)
# Requirement already satisfied: packaging in /root/venv/lib/python3.12/site-packages (from brian2->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (12.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: setuptools-scm in /root/venv/lib/python3.12/site-packages (from brian2tools->-r requirements.txt (line 3)) (9.2.2)
# Requirement already satisfied: pylems>=0.4.9 in /root/venv/lib/python3.12/site-packages (from brian2tools->-r requirements.txt (line 3)) (0.6.8)
# Requirement already satisfied: libNeuroML>=0.2.18 in /root/venv/lib/python3.12/site-packages (from brian2tools->-r requirements.txt (line 3)) (0.6.7)
# Requirement already satisfied: markdown-strings in /root/venv/lib/python3.12/site-packages (from brian2tools->-r requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.12/site-packages (from jinja2>=2.7->brian2->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: lxml in /root/venv/lib/python3.12/site-packages (from libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: networkx in /root/venv/lib/python3.12/site-packages (from libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (3.5)
# Requirement already satisfied: tables>3.10 in /root/venv/lib/python3.12/site-packages (from libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (3.10.2)
# Requirement already satisfied: natsort in /root/venv/lib/python3.12/site-packages (from libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (8.4.0)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /root/venv/lib/python3.12/site-packages (from sympy>=1.2->brian2->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: numexpr>=2.6.2 in /root/venv/lib/python3.12/site-packages (from tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (2.14.1)
# Requirement already satisfied: py-cpuinfo in /root/venv/lib/python3.12/site-packages (from tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /root/venv/lib/python3.12/site-packages (from tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (3.11.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /root/venv/lib/python3.12/site-packages (from tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: ndindex in /root/venv/lib/python3.12/site-packages (from blosc2>=2.3.0->tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (1.10.0)
# Requirement already satisfied: msgpack in /root/venv/lib/python3.12/site-packages (from blosc2>=2.3.0->tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (1.1.2)
# Requirement already satisfied: platformdirs in /root/venv/lib/python3.12/site-packages (from blosc2>=2.3.0->tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (4.5.0)
# Requirement already satisfied: requests in /root/venv/lib/python3.12/site-packages (from blosc2>=2.3.0->tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/venv/lib/python3.12/site-packages (from requests->blosc2>=2.3.0->tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.12/site-packages (from requests->blosc2>=2.3.0->tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.12/site-packages (from requests->blosc2>=2.3.0->tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.12/site-packages (from requests->blosc2>=2.3.0->tables>3.10->libNeuroML>=0.2.18->brian2tools->-r requirements.txt (line 3)) (2025.10.5)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
from brian2 import *
import numpy as np
import matplotlib.pyplot as plt

# Switching off Brian's C++ code generation (not useful here)
prefs.codegen.target = 'auto'

# %% [markdown]
# ## Convenience plot functions

# %%
# some minor plot tweaks
plt.rcParams.update({'axes.spines.top': False, 'axes.spines.right': False,
                     'lines.linewidth': 2, 'lines.markeredgewidth': 2})

def hh_plot(monitor, idx=0, xlim=None):
    fig, axs = plt.subplots(4, 1, figsize=(12, 6), sharex=True, layout="constrained")
    axs[0].plot(monitor.t/ms, monitor.V[idx]/mV)
    axs[0].set(ylabel='V (mV)')
    axs[1].plot(monitor.t/ms, monitor.I_L[idx]/nA, label=r'$I_\text{L}$')
    axs[1].plot(monitor.t/ms, monitor.I_Na[idx]/nA, label=r'$I_\text{Na}$')
    axs[1].plot(monitor.t/ms, monitor.I_K[idx]/nA, label=r'$I_\text{K}$')
    axs[1].set(ylabel='I (nA)')
    axs[1].legend()
    axs[2].plot(monitor.t/ms, monitor.g_Na[idx]/uS, label=r'$g_\text{Na}$', color='C1')
    axs[2].plot(monitor.t/ms, monitor.g_K[idx]/uS, label=r'$g_\text{K}$', color='C2')
    axs[2].set(ylabel='g (µS)')
    axs[2].legend()
    axs[3].plot(monitor.t/ms, monitor.m[idx], label='$m$')
    axs[3].plot(monitor.t/ms, monitor.h[idx], label='$h$')
    axs[3].plot(monitor.t/ms, monitor.n[idx], label='$n$')
    axs[3].set(ylim=(-0.1, 1.1))
    axs[3].legend()
    axs[3].set_xlabel('t (ms)')
    if xlim is not None:
        axs[3].set_xlim(xlim)

def compare_hh_lif(monitor_hh, monitor_lif, spike_mon_lif, idx=0, xlim=None):
    lif_spikes = spike_mon_lif.spike_trains()[idx]
    fig, axs = plt.subplot_mosaic("""AB
                                     AC""", sharex=True, layout="constrained", figsize=(12, 4))
    axs["A"].plot(monitor_hh.t/ms, monitor_hh.V[idx]/mV, label='HH')
    axs["A"].plot(monitor_lif.t/ms, monitor_lif.V[idx]/mV, label='LIF')
    axs["A"].vlines(lif_spikes/ms, -50, 50, color='C1')  # Plot vertical lines for each spike
    axs["A"].legend()
    axs["A"].set(ylabel='V (mV)', xlabel='t (ms)')

    axs["B"].plot(monitor_hh.t/ms, monitor_hh.V[idx]/mV)
    axs["B"].set(ylabel='V (mV)')

    axs["C"].plot(monitor_lif.t/ms, monitor_lif.V[idx]/mV, color='C1')
    axs["C"].vlines(lif_spikes/ms, -50, 50, color='C1')
    axs["C"].set(ylabel='V (mV)', xlabel='t (ms)')

def compare_fI_curves(I_stim, spike_mon_hh, spike_mon_lif):
    fig, ax = plt.subplots(figsize=(6, 4), layout="constrained")
    ax.plot(I_stim/nA, spike_mon_hh.count, label='HH')
    ax.plot(I_stim/nA, spike_mon_lif.count, label='LIF')
    ax.legend()
    ax.set(xlabel='I (nA)', ylabel='spike count')

# %% [markdown]
# ## Physical quantities
# Brian has a system for physical quantities, handling units and checking for dimensional consistency.

# %%
x = 1*mV
y = 2*ms
print(y + x)
# Out:
# ---------------------------------------------------------------------------
# DimensionMismatchError                    Traceback (most recent call last)
# Cell In[10], line 3
#       1 x = 1*mV
#       2 y = 2*ms
# ----> 3 print(y + x)
#
# File ~/venv/lib/python3.12/site-packages/brian2/units/fundamentalunits.py:1193, in Quantity.__array_ufunc__(self, uf, method, *inputs, **kwargs)
#    1190 elif uf.__name__ in UFUNCS_MATCHING_DIMENSIONS + UFUNCS_COMPARISONS:
#    1191     # Ok if dimension of arguments match (for reductions, they always do)
#    1192     if method == "__call__":
# -> 1193         fail_for_dimension_mismatch(
#    1194             inputs[0],
#    1195             inputs[1],
#    1196             error_message=(
#    1197                 "Cannot calculate {val1} %s {val2}, the units do not match"
#    1198             )
#    1199             % uf.__name__,
#    1200             val1=inputs[0],
#    1201             val2=inputs[1],
#    1202         )
#    1203     if uf.__name__ in UFUNCS_COMPARISONS:
#    1204         return uf_method(*[np.asarray(i) for i in inputs], **kwargs)
#
# File ~/venv/lib/python3.12/site-packages/brian2/units/fundamentalunits.py:266, in fail_for_dimension_mismatch(obj1, obj2, error_message, **error_quantities)
#     264         raise DimensionMismatchError(error_message, dim1)
#     265     else:
# --> 266         raise DimensionMismatchError(error_message, dim1, dim2)
#     267 else:
#     268     return dim1, dim2
#
# DimensionMismatchError: Cannot calculate 2. ms add 1. mV, the units do not match (units are s and V).

# %% [markdown]
# ## The Hodgkin-Huxley model

# %% [markdown]
# <img src="image-20241024-180844.png" width="" align="" />

# %%
# Parameters/rate functions are reasonable for a cortical neuron

area = 20000*umetre**2
C = (1*ufarad*cm**-2) * area
g_L = (50*usiemens*cm**-2) * area
VT = -52
E_L = -60*mV
E_K = -90*mV
E_Na = 50*mV
gbar_Na = (100*msiemens*cm**-2) * area
gbar_K = (30*msiemens*cm**-2) * area

# Equations
hh_eqs = """
dV/dt = (I_L + I_Na + I_K + I_stim)/C : volt
I_L = g_L*(E_L - V) : amp
I_Na = g_Na*(E_Na - V) : amp
g_Na = gbar_Na*m**3*h : siemens
I_K = g_K*(E_K - V) : amp
g_K = gbar_K*n**4 : siemens

dn/dt = (n_inf - n)/tau_n : 1
tau_n = 1/(alpha_n + beta_n) : second
n_inf = alpha_n/(alpha_n + beta_n) : 1

dm/dt = (m_inf - m)/tau_m : 1
tau_m = 1/(alpha_m + beta_m) : second
m_inf = alpha_m/(alpha_m + beta_m) : 1

dh/dt = (h_inf - h)/tau_h : 1
tau_h = 1/(alpha_h + beta_h) : second
h_inf = alpha_h/(alpha_h + beta_h) : 1

V_ = V/mV : 1  # for shorter equations below
alpha_m = 0.32*4/exprel((13-V_+VT)/4)/ms : Hz
beta_m = 0.28*5/exprel((V_-VT-40)/5)/ms : Hz
alpha_h = 0.128*exp((17-V_+VT)/18)/ms : Hz
beta_h = 4./(1+exp((40-V_+VT)/5))/ms : Hz
alpha_n = 0.032*5/exprel((15-V_+VT)/5)/ms : Hz
beta_n = .5*exp((10-V_+VT)/40)/ms : Hz
I_stim : amp (constant)
"""

# %%
start_scope()

neuron = NeuronGroup(1, hh_eqs, method="exponential_euler")
neuron.V = E_L
neuron.I_stim = 0.5*nA
mon = StateMonitor(neuron, True, record=True)

run(300*ms)

# %%
hh_plot(mon)

# %%
start_scope()

neuron = NeuronGroup(1, hh_eqs, threshold="V>20*mV", refractory=2*ms, method="exponential_euler")
neuron.V = E_L
neuron.I_stim = 0.5*nA
mon = StateMonitor(neuron, True, record=True)
spike_mon = SpikeMonitor(neuron)
run(300*ms)

# %%
print("Number of spikes", spike_mon.count)
print("Inter-spike intervals:", np.diff(spike_mon.t)
# Out:
#   Cell In[30], line 2
#     print("Inter-spike intervals:", np.diff(spike_mon.t)
#                                                         ^
# SyntaxError: incomplete input

# %% [markdown]
# ## f/I curve (firing rate as function of input)

# %%
start_scope()

neuron = NeuronGroup(50, hh_eqs, threshold="V>20*mV", refractory=2*ms, method="exponential_euler")
neuron.V = E_L
neuron.I_stim = np.linspace(0, 1, 50)*nA
mon = StateMonitor(neuron, True, record=True)
spike_mon = SpikeMonitor(neuron)
runtime = 3*second
run(runtime, report="text")
# Out:
# Starting simulation at t=0. s for a duration of 3. s
# 3. s (100%) simulated in 7s

# %%
plt.plot(neuron.I_stim/nA, spike_mon.count/runtime);

# %% [markdown]
# ## The LIF model (leaky integrate-and-fire neuron)

# %%
# Equations

prefs.codegen.target = "numpy"
lif_eqs= """
dV/dt = (g_L*(E_L - V) + I_stim)/C : volt
I_stim : amp (constant)
"""

# %%
start_scope()
neuron  = NeuronGroup(1, lif_eqs, threshold="V>-50*mV", reset="V=-80*mV", refractory=2*ms, method="exact")
neuron.I_stim = 0.5*nA

mon = StateMonitor(neuron, True, record=True)
spike_mon = SpikeMonitor(neuron)
runtime = 3*second
run(runtime, report="text")
# Out:
# Starting simulation at t=0. s for a duration of 3. s
# 3. s (100%) simulated in 2s

# %%
plt.plot(mon.t/ms, mon.V[0]/mV);  plt.xlim(100,  200)
plt.vlines(spike_mon.t/ms,-50, 50)

# %% [markdown]
# ## Comparing the LIF to the HH model

# %%
start_scope()

hh_neurons = NeuronGroup(1, hh_eqs, threshold="V>-20*mV", refractory=5*ms, method='exponential_euler')
hh_neurons.V = E_L
hh_neurons.I_stim = 0.5*nA

neurons = NeuronGroup(1, lif_eqs, threshold="V>-50*mV", reset="V = -70*mV",
                      refractory=2*ms, method='exact')
neurons.V = E_L
neurons.I_stim = 0.5*nA

hh_mon = StateMonitor(hh_neurons, "V", record=True)
mon = StateMonitor(neurons, "V", record=True)
spike_mon = SpikeMonitor(neurons)
run(300*ms)

# %%
compare_hh_lif(hh_mon, mon, spike_mon)

# %%
start_scope()

hh_neurons = NeuronGroup(50, hh_eqs, threshold="V>-20*mV", refractory=5*ms, method='exponential_euler')
hh_neurons.V = E_L
hh_neurons.I_stim = 0.5*nA

neurons = NeuronGroup(50, lif_eqs, threshold="V>-50*mV", reset="V = -70*mV",
                      refractory=2*ms, method='exact')
neurons.V = E_L
neurons.I_stim = np.linspace(0, 1, len(neurons))*nA

hh_mon = StateMonitor(hh_neurons, "V", record=True)
mon = StateMonitor(neurons, "V", record=True)
spike_mon = SpikeMonitor(neurons)
spike_mon_hh = SpikeMonitor(hh_neurons)

run(300*ms)

# %%
compare_fI_curves(neurons.I_stim, spike_mon_hh, spike_mon)

# %% [markdown]
# ## Apendix
#
# Best fit for the HH model:
# ```
# threshold="V>-46.36*mV", reset="V = -89.62*mV", refractory=2.43*ms
# ```

# %% [markdown]
# <hr>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7c065da6-9461-4b88-9b62-cc4140a9e456' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
